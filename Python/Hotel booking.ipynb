# %% [markdown]
# # Hotel Booking

# %% [markdown]
# ##  Data Acquisiton, Cleaning, and Feature Engineering

# %% [markdown]
# ## 1. Load Dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('hotel_bookings_resort.csv')
df.head()
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...      DepositType        Agent  \
# 0                  0       2         0  ...  No Deposit              NULL
# 1                  0       2         0  ...  No Deposit              NULL
# 2                  1       1         0  ...  No Deposit              NULL
# 3                  1       1         0  ...  No Deposit               304
# 4                  2       2         0  ...  No Deposit               240
#
#        Company DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0         NULL                 0    Transient   0.0                         0
# 1         NULL                 0    Transient   0.0                         0
# 2         NULL                 0    Transient  75.0                         0
# 3         NULL                 0    Transient  75.0                         0
# 4         NULL                 0    Transient  98.0                         0
#
#    TotalOfSpecialRequests ReservationStatus ReservationStatusDate
# 0                       0         Check-Out            2015-07-01
# 1                       0         Check-Out            2015-07-01
# 2                       0         Check-Out            2015-07-02
# 3                       0         Check-Out            2015-07-02
# 4                       1         Check-Out            2015-07-03
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#          IsCanceled      LeadTime  ArrivalDateYear  ArrivalDateWeekNumber  \
# count  40060.000000  40060.000000     40060.000000           40060.000000
# mean       0.277634     92.675686      2016.121443              27.140864
# std        0.447837     97.285315         0.722347              14.005441
# min        0.000000      0.000000      2015.000000               1.000000
# 25%        0.000000     10.000000      2016.000000              16.000000
# 50%        0.000000     57.000000      2016.000000              28.000000
# 75%        1.000000    155.000000      2017.000000              38.000000
# max        1.000000    737.000000      2017.000000              53.000000
#
#        ArrivalDateDayOfMonth  StaysInWeekendNights  StaysInWeekNights  \
# count           40060.000000          40060.000000       40060.000000
# mean               15.821243              1.189815           3.128732
# std                 8.883708              1.147812           2.461329
# min                 1.000000              0.000000           0.000000
# 25%                 8.000000              0.000000           1.000000
# 50%                16.000000              1.000000           3.000000
# 75%                24.000000              2.000000           5.000000
# max                31.000000             19.000000          50.000000
#
#              Adults      Children        Babies  IsRepeatedGuest  \
# count  40060.000000  40060.000000  40060.000000     40060.000000
# mean       1.867149      0.128682      0.013904         0.044383
# std        0.697285      0.445195      0.118998         0.205948
# min        0.000000      0.000000      0.000000         0.000000
# 25%        2.000000      0.000000      0.000000         0.000000
# 50%        2.000000      0.000000      0.000000         0.000000
# 75%        2.000000      0.000000      0.000000         0.000000
# max       55.000000     10.000000      2.000000         1.000000
#
#        PreviousCancellations  PreviousBookingsNotCanceled  BookingChanges  \
# count           40060.000000                 40060.000000    40060.000000
# mean                0.101722                     0.146455        0.287968
# std                 1.335115                     1.001955        0.726548
# min                 0.000000                     0.000000        0.000000
# 25%                 0.000000                     0.000000        0.000000
# 50%                 0.000000                     0.000000        0.000000
# 75%                 0.000000                     0.000000        0.000000
# max                26.000000                    30.000000       17.000000
#
#        DaysInWaitingList           ADR  RequiredCarParkingSpaces  \
# count       40060.000000  40060.000000              40060.000000
# mean            0.527758     94.952930                  0.138068
# std             7.428580     61.442418                  0.351001
# min             0.000000     -6.380000                  0.000000
# 25%             0.000000     50.000000                  0.000000
# 50%             0.000000     75.000000                  0.000000
# 75%             0.000000    125.000000                  0.000000
# max           185.000000    508.000000                  8.000000
#
#        TotalOfSpecialRequests
# count             40060.00000
# mean                  0.61977
# std                   0.81393
# min                   0.00000
# 25%                   0.00000
# 50%                   0.00000
# 75%                   1.00000
# max                   5.00000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40060 entries, 0 to 40059
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   IsCanceled                   40060 non-null  int64
#  1   LeadTime                     40060 non-null  int64
#  2   ArrivalDateYear              40060 non-null  int64
#  3   ArrivalDateMonth             40060 non-null  str
#  4   ArrivalDateWeekNumber        40060 non-null  int64
#  5   ArrivalDateDayOfMonth        40060 non-null  int64
#  6   StaysInWeekendNights         40060 non-null  int64
#  7   StaysInWeekNights            40060 non-null  int64
#  8   Adults                       40060 non-null  int64
#  9   Children                     40060 non-null  int64
#  10  Babies                       40060 non-null  int64
#  11  Meal                         40060 non-null  str
#  12  Country                      39596 non-null  str
#  13  MarketSegment                40060 non-null  str
#  14  DistributionChannel          40060 non-null  str
#  15  IsRepeatedGuest              40060 non-null  int64
#  16  PreviousCancellations        40060 non-null  int64
#  17  PreviousBookingsNotCanceled  40060 non-null  int64
#  18  ReservedRoomType             40060 non-null  str
#  19  AssignedRoomType             40060 non-null  str
#  20  BookingChanges               40060 non-null  int64
#  21  DepositType                  40060 non-null  str
#  22  Agent                        40060 non-null  str
#  23  Company                      40060 non-null  str
#  24  DaysInWaitingList            40060 non-null  int64
#  25  CustomerType                 40060 non-null  str
#  26  ADR                          40060 non-null  float64
#  27  RequiredCarParkingSpaces     40060 non-null  int64
#  28  TotalOfSpecialRequests       40060 non-null  int64
#  29  ReservationStatus            40060 non-null  str
#  30  ReservationStatusDate        40060 non-null  str
# dtypes: float64(1), int64(17), str(13)
# memory usage: 9.5 MB

# %% [markdown]
# ## 2. Handle 'NULL' Text Values

# %%
# Strip spaces
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# Replace NULL-like values
null_values = ['NULL', 'null', 'NaN', 'nan', 'None', '']
df = df.replace(null_values, np.nan)

df.isnull().sum()
# Out:
# IsCanceled                       0
# LeadTime                         0
# ArrivalDateYear                  0
# ArrivalDateMonth                 0
# ArrivalDateWeekNumber            0
# ArrivalDateDayOfMonth            0
# StaysInWeekendNights             0
# StaysInWeekNights                0
# Adults                           0
# Children                         0
# Babies                           0
# Meal                             0
# Country                        464
# MarketSegment                    0
# DistributionChannel              0
# IsRepeatedGuest                  0
# PreviousCancellations            0
# PreviousBookingsNotCanceled      0
# ReservedRoomType                 0
# AssignedRoomType                 0
# BookingChanges                   0
# DepositType                      0
# Agent                            0
# Company                          0
# DaysInWaitingList                0
# CustomerType                     0
# ADR                              0
# RequiredCarParkingSpaces         0
# TotalOfSpecialRequests           0
# ReservationStatus                0
# ReservationStatusDate            0
# dtype: int64

# %%
df.head()
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...      DepositType        Agent  \
# 0                  0       2         0  ...  No Deposit              NULL
# 1                  0       2         0  ...  No Deposit              NULL
# 2                  1       1         0  ...  No Deposit              NULL
# 3                  1       1         0  ...  No Deposit               304
# 4                  2       2         0  ...  No Deposit               240
#
#        Company DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0         NULL                 0    Transient   0.0                         0
# 1         NULL                 0    Transient   0.0                         0
# 2         NULL                 0    Transient  75.0                         0
# 3         NULL                 0    Transient  75.0                         0
# 4         NULL                 0    Transient  98.0                         0
#
#    TotalOfSpecialRequests ReservationStatus ReservationStatusDate
# 0                       0         Check-Out            2015-07-01
# 1                       0         Check-Out            2015-07-01
# 2                       0         Check-Out            2015-07-02
# 3                       0         Check-Out            2015-07-02
# 4                       1         Check-Out            2015-07-03
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40060 entries, 0 to 40059
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   IsCanceled                   40060 non-null  int64
#  1   LeadTime                     40060 non-null  int64
#  2   ArrivalDateYear              40060 non-null  int64
#  3   ArrivalDateMonth             40060 non-null  str
#  4   ArrivalDateWeekNumber        40060 non-null  int64
#  5   ArrivalDateDayOfMonth        40060 non-null  int64
#  6   StaysInWeekendNights         40060 non-null  int64
#  7   StaysInWeekNights            40060 non-null  int64
#  8   Adults                       40060 non-null  int64
#  9   Children                     40060 non-null  int64
#  10  Babies                       40060 non-null  int64
#  11  Meal                         40060 non-null  str
#  12  Country                      40060 non-null  str
#  13  MarketSegment                40060 non-null  str
#  14  DistributionChannel          40060 non-null  str
#  15  IsRepeatedGuest              40060 non-null  int64
#  16  PreviousCancellations        40060 non-null  int64
#  17  PreviousBookingsNotCanceled  40060 non-null  int64
#  18  ReservedRoomType             40060 non-null  str
#  19  AssignedRoomType             40060 non-null  str
#  20  BookingChanges               40060 non-null  int64
#  21  DepositType                  40060 non-null  str
#  22  Agent                        40060 non-null  str
#  23  Company                      40060 non-null  str
#  24  DaysInWaitingList            40060 non-null  int64
#  25  CustomerType                 40060 non-null  str
#  26  ADR                          40060 non-null  float64
#  27  RequiredCarParkingSpaces     40060 non-null  int64
#  28  TotalOfSpecialRequests       40060 non-null  int64
#  29  ReservationStatus            40060 non-null  str
#  30  ReservationStatusDate        40060 non-null  str
# dtypes: float64(1), int64(17), str(13)
# memory usage: 9.5 MB

# %% [markdown]
# ## 3. Missing Value Treatment

# %%
cat_cols = df.select_dtypes(include=['object', 'str']).columns

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.head()
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...      DepositType        Agent  \
# 0                  0       2         0  ...  No Deposit              NULL
# 1                  0       2         0  ...  No Deposit              NULL
# 2                  1       1         0  ...  No Deposit              NULL
# 3                  1       1         0  ...  No Deposit               304
# 4                  2       2         0  ...  No Deposit               240
#
#        Company DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0         NULL                 0    Transient   0.0                         0
# 1         NULL                 0    Transient   0.0                         0
# 2         NULL                 0    Transient  75.0                         0
# 3         NULL                 0    Transient  75.0                         0
# 4         NULL                 0    Transient  98.0                         0
#
#    TotalOfSpecialRequests ReservationStatus ReservationStatusDate
# 0                       0         Check-Out            2015-07-01
# 1                       0         Check-Out            2015-07-01
# 2                       0         Check-Out            2015-07-02
# 3                       0         Check-Out            2015-07-02
# 4                       1         Check-Out            2015-07-03
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40060 entries, 0 to 40059
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   IsCanceled                   40060 non-null  int64
#  1   LeadTime                     40060 non-null  int64
#  2   ArrivalDateYear              40060 non-null  int64
#  3   ArrivalDateMonth             40060 non-null  str
#  4   ArrivalDateWeekNumber        40060 non-null  int64
#  5   ArrivalDateDayOfMonth        40060 non-null  int64
#  6   StaysInWeekendNights         40060 non-null  int64
#  7   StaysInWeekNights            40060 non-null  int64
#  8   Adults                       40060 non-null  int64
#  9   Children                     40060 non-null  int64
#  10  Babies                       40060 non-null  int64
#  11  Meal                         40060 non-null  str
#  12  Country                      40060 non-null  str
#  13  MarketSegment                40060 non-null  str
#  14  DistributionChannel          40060 non-null  str
#  15  IsRepeatedGuest              40060 non-null  int64
#  16  PreviousCancellations        40060 non-null  int64
#  17  PreviousBookingsNotCanceled  40060 non-null  int64
#  18  ReservedRoomType             40060 non-null  str
#  19  AssignedRoomType             40060 non-null  str
#  20  BookingChanges               40060 non-null  int64
#  21  DepositType                  40060 non-null  str
#  22  Agent                        40060 non-null  str
#  23  Company                      40060 non-null  str
#  24  DaysInWaitingList            40060 non-null  int64
#  25  CustomerType                 40060 non-null  str
#  26  ADR                          40060 non-null  float64
#  27  RequiredCarParkingSpaces     40060 non-null  int64
#  28  TotalOfSpecialRequests       40060 non-null  int64
#  29  ReservationStatus            40060 non-null  str
#  30  ReservationStatusDate        40060 non-null  str
# dtypes: float64(1), int64(17), str(13)
# memory usage: 9.5 MB

# %% [markdown]
# ## 4. Remove Duplicates

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...      DepositType        Agent  \
# 0                  0       2         0  ...  No Deposit              NULL
# 1                  0       2         0  ...  No Deposit              NULL
# 2                  1       1         0  ...  No Deposit              NULL
# 3                  1       1         0  ...  No Deposit               304
# 4                  2       2         0  ...  No Deposit               240
#
#        Company DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0         NULL                 0    Transient   0.0                         0
# 1         NULL                 0    Transient   0.0                         0
# 2         NULL                 0    Transient  75.0                         0
# 3         NULL                 0    Transient  75.0                         0
# 4         NULL                 0    Transient  98.0                         0
#
#    TotalOfSpecialRequests ReservationStatus ReservationStatusDate
# 0                       0         Check-Out            2015-07-01
# 1                       0         Check-Out            2015-07-01
# 2                       0         Check-Out            2015-07-02
# 3                       0         Check-Out            2015-07-02
# 4                       1         Check-Out            2015-07-03
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 33949 entries, 0 to 40059
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   IsCanceled                   33949 non-null  int64
#  1   LeadTime                     33949 non-null  int64
#  2   ArrivalDateYear              33949 non-null  int64
#  3   ArrivalDateMonth             33949 non-null  str
#  4   ArrivalDateWeekNumber        33949 non-null  int64
#  5   ArrivalDateDayOfMonth        33949 non-null  int64
#  6   StaysInWeekendNights         33949 non-null  int64
#  7   StaysInWeekNights            33949 non-null  int64
#  8   Adults                       33949 non-null  int64
#  9   Children                     33949 non-null  int64
#  10  Babies                       33949 non-null  int64
#  11  Meal                         33949 non-null  str
#  12  Country                      33949 non-null  str
#  13  MarketSegment                33949 non-null  str
#  14  DistributionChannel          33949 non-null  str
#  15  IsRepeatedGuest              33949 non-null  int64
#  16  PreviousCancellations        33949 non-null  int64
#  17  PreviousBookingsNotCanceled  33949 non-null  int64
#  18  ReservedRoomType             33949 non-null  str
#  19  AssignedRoomType             33949 non-null  str
#  20  BookingChanges               33949 non-null  int64
#  21  DepositType                  33949 non-null  str
#  22  Agent                        33949 non-null  str
#  23  Company                      33949 non-null  str
#  24  DaysInWaitingList            33949 non-null  int64
#  25  CustomerType                 33949 non-null  str
#  26  ADR                          33949 non-null  float64
#  27  RequiredCarParkingSpaces     33949 non-null  int64
#  28  TotalOfSpecialRequests       33949 non-null  int64
#  29  ReservationStatus            33949 non-null  str
#  30  ReservationStatusDate        33949 non-null  str
# dtypes: float64(1), int64(17), str(13)
# memory usage: 8.3 MB

# %% [markdown]
# ## 5. Fix Data Types

# %%
for col in df.columns:
    try:
        df[col] = pd.to_numeric(df[col])
    except (ValueError, TypeError):
        pass

# %%
df.head()
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...  DepositType  Agent Company  \
# 0                  0       2         0  ...   No Deposit    NaN     NaN
# 1                  0       2         0  ...   No Deposit    NaN     NaN
# 2                  1       1         0  ...   No Deposit    NaN     NaN
# 3                  1       1         0  ...   No Deposit  304.0     NaN
# 4                  2       2         0  ...   No Deposit  240.0     NaN
#
#   DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0                 0    Transient   0.0                         0
# 1                 0    Transient   0.0                         0
# 2                 0    Transient  75.0                         0
# 3                 0    Transient  75.0                         0
# 4                 0    Transient  98.0                         0
#
#    TotalOfSpecialRequests ReservationStatus ReservationStatusDate
# 0                       0         Check-Out            2015-07-01
# 1                       0         Check-Out            2015-07-01
# 2                       0         Check-Out            2015-07-02
# 3                       0         Check-Out            2015-07-02
# 4                       1         Check-Out            2015-07-03
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 6.Standardize Column Names

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#    iscanceled  leadtime  arrivaldateyear arrivaldatemonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    arrivaldateweeknumber  arrivaldatedayofmonth  staysinweekendnights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    staysinweeknights  adults  children  ...      deposittype        agent  \
# 0                  0       2         0  ...  No Deposit              NULL
# 1                  0       2         0  ...  No Deposit              NULL
# 2                  1       1         0  ...  No Deposit              NULL
# 3                  1       1         0  ...  No Deposit               304
# 4                  2       2         0  ...  No Deposit               240
#
#        company daysinwaitinglist customertype   adr  requiredcarparkingspaces  \
# 0         NULL                 0    Transient   0.0                         0
# 1         NULL                 0    Transient   0.0                         0
# 2         NULL                 0    Transient  75.0                         0
# 3         NULL                 0    Transient  75.0                         0
# 4         NULL                 0    Transient  98.0                         0
#
#    totalofspecialrequests reservationstatus reservationstatusdate
# 0                       0         Check-Out            2015-07-01
# 1                       0         Check-Out            2015-07-01
# 2                       0         Check-Out            2015-07-02
# 3                       0         Check-Out            2015-07-02
# 4                       1         Check-Out            2015-07-03
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 33949 entries, 0 to 40059
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iscanceled                   33949 non-null  int64
#  1   leadtime                     33949 non-null  int64
#  2   arrivaldateyear              33949 non-null  int64
#  3   arrivaldatemonth             33949 non-null  str
#  4   arrivaldateweeknumber        33949 non-null  int64
#  5   arrivaldatedayofmonth        33949 non-null  int64
#  6   staysinweekendnights         33949 non-null  int64
#  7   staysinweeknights            33949 non-null  int64
#  8   adults                       33949 non-null  int64
#  9   children                     33949 non-null  int64
#  10  babies                       33949 non-null  int64
#  11  meal                         33949 non-null  str
#  12  country                      33949 non-null  str
#  13  marketsegment                33949 non-null  str
#  14  distributionchannel          33949 non-null  str
#  15  isrepeatedguest              33949 non-null  int64
#  16  previouscancellations        33949 non-null  int64
#  17  previousbookingsnotcanceled  33949 non-null  int64
#  18  reservedroomtype             33949 non-null  str
#  19  assignedroomtype             33949 non-null  str
#  20  bookingchanges               33949 non-null  int64
#  21  deposittype                  33949 non-null  str
#  22  agent                        33949 non-null  str
#  23  company                      33949 non-null  str
#  24  daysinwaitinglist            33949 non-null  int64
#  25  customertype                 33949 non-null  str
#  26  adr                          33949 non-null  float64
#  27  requiredcarparkingspaces     33949 non-null  int64
#  28  totalofspecialrequests       33949 non-null  int64
#  29  reservationstatus            33949 non-null  str
#  30  reservationstatusdate        33949 non-null  str
# dtypes: float64(1), int64(17), str(13)
# memory usage: 8.3 MB

# %%
df['reservationstatusdate'] = pd.to_datetime(
    df['reservationstatusdate'],
    format='%Y-%m-%d',   # enforce correct format
    errors='coerce'
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 33949 entries, 0 to 40059
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iscanceled                   33949 non-null  int64
#  1   leadtime                     33949 non-null  int64
#  2   arrivaldateyear              33949 non-null  int64
#  3   arrivaldatemonth             33949 non-null  str
#  4   arrivaldateweeknumber        33949 non-null  int64
#  5   arrivaldatedayofmonth        33949 non-null  int64
#  6   staysinweekendnights         33949 non-null  int64
#  7   staysinweeknights            33949 non-null  int64
#  8   adults                       33949 non-null  int64
#  9   children                     33949 non-null  int64
#  10  babies                       33949 non-null  int64
#  11  meal                         33949 non-null  str
#  12  country                      33949 non-null  str
#  13  marketsegment                33949 non-null  str
#  14  distributionchannel          33949 non-null  str
#  15  isrepeatedguest              33949 non-null  int64
#  16  previouscancellations        33949 non-null  int64
#  17  previousbookingsnotcanceled  33949 non-null  int64
#  18  reservedroomtype             33949 non-null  str
#  19  assignedroomtype             33949 non-null  str
#  20  bookingchanges               33949 non-null  int64
#  21  deposittype                  33949 non-null  str
#  22  agent                        33949 non-null  str
#  23  company                      33949 non-null  str
#  24  daysinwaitinglist            33949 non-null  int64
#  25  customertype                 33949 non-null  str
#  26  adr                          33949 non-null  float64
#  27  requiredcarparkingspaces     33949 non-null  int64
#  28  totalofspecialrequests       33949 non-null  int64
#  29  reservationstatus            33949 non-null  str
#  30  reservationstatusdate        33949 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(1), int64(17), str(12)
# memory usage: 8.3 MB

# %%
df.head()
# Out:
#    iscanceled  leadtime  arrivaldateyear arrivaldatemonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    arrivaldateweeknumber  arrivaldatedayofmonth  staysinweekendnights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    staysinweeknights  adults  children  ...      deposittype        agent  \
# 0                  0       2         0  ...  No Deposit              NULL
# 1                  0       2         0  ...  No Deposit              NULL
# 2                  1       1         0  ...  No Deposit              NULL
# 3                  1       1         0  ...  No Deposit               304
# 4                  2       2         0  ...  No Deposit               240
#
#        company daysinwaitinglist customertype   adr  requiredcarparkingspaces  \
# 0         NULL                 0    Transient   0.0                         0
# 1         NULL                 0    Transient   0.0                         0
# 2         NULL                 0    Transient  75.0                         0
# 3         NULL                 0    Transient  75.0                         0
# 4         NULL                 0    Transient  98.0                         0
#
#    totalofspecialrequests reservationstatus reservationstatusdate
# 0                       0         Check-Out            2015-07-01
# 1                       0         Check-Out            2015-07-01
# 2                       0         Check-Out            2015-07-02
# 3                       0         Check-Out            2015-07-02
# 4                       1         Check-Out            2015-07-03
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 6. Feature Engineering

# %%
df['totalstay'] = df['staysinweeknights'] + df['staysinweekendnights']

# %%
df['res_year'] = df['reservationstatusdate'].dt.year
df['res_month'] = df['reservationstatusdate'].dt.month
df['res_day'] = df['reservationstatusdate'].dt.day
df['res_weekday'] = df['reservationstatusdate'].dt.weekday

# %%
df['pricepernight'] = df['adr'] / (df['staysinweekendnights'] + 1)

# %%
df.head()
# Out:
#    iscanceled  leadtime  arrivaldateyear arrivaldatemonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    arrivaldateweeknumber  arrivaldatedayofmonth  staysinweekendnights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    staysinweeknights  adults  children  ...  requiredcarparkingspaces  \
# 0                  0       2         0  ...                         0
# 1                  0       2         0  ...                         0
# 2                  1       1         0  ...                         0
# 3                  1       1         0  ...                         0
# 4                  2       2         0  ...                         0
#
#   totalofspecialrequests reservationstatus reservationstatusdate totalstay  \
# 0                      0         Check-Out            2015-07-01         0
# 1                      0         Check-Out            2015-07-01         0
# 2                      0         Check-Out            2015-07-02         1
# 3                      0         Check-Out            2015-07-02         1
# 4                      1         Check-Out            2015-07-03         2
#
#    res_year  res_month  res_day res_weekday pricepernight
# 0      2015          7        1           2           0.0
# 1      2015          7        1           2           0.0
# 2      2015          7        2           3          75.0
# 3      2015          7        2           3          75.0
# 4      2015          7        3           4          98.0
#
# [5 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 33949 entries, 0 to 40059
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iscanceled                   33949 non-null  int64
#  1   leadtime                     33949 non-null  int64
#  2   arrivaldateyear              33949 non-null  int64
#  3   arrivaldatemonth             33949 non-null  str
#  4   arrivaldateweeknumber        33949 non-null  int64
#  5   arrivaldatedayofmonth        33949 non-null  int64
#  6   staysinweekendnights         33949 non-null  int64
#  7   staysinweeknights            33949 non-null  int64
#  8   adults                       33949 non-null  int64
#  9   children                     33949 non-null  int64
#  10  babies                       33949 non-null  int64
#  11  meal                         33949 non-null  str
#  12  country                      33949 non-null  str
#  13  marketsegment                33949 non-null  str
#  14  distributionchannel          33949 non-null  str
#  15  isrepeatedguest              33949 non-null  int64
#  16  previouscancellations        33949 non-null  int64
#  17  previousbookingsnotcanceled  33949 non-null  int64
#  18  reservedroomtype             33949 non-null  str
#  19  assignedroomtype             33949 non-null  str
#  20  bookingchanges               33949 non-null  int64
#  21  deposittype                  33949 non-null  str
#  22  agent                        33949 non-null  str
#  23  company                      33949 non-null  str
#  24  daysinwaitinglist            33949 non-null  int64
#  25  customertype                 33949 non-null  str
#  26  adr                          33949 non-null  float64
#  27  requiredcarparkingspaces     33949 non-null  int64
#  28  totalofspecialrequests       33949 non-null  int64
#  29  reservationstatus            33949 non-null  str
#  30  reservationstatusdate        33949 non-null  datetime64[us]
#  31  totalstay                    33949 non-null  int64
#  32  res_year                     33949 non-null  int32
#  33  res_month                    33949 non-null  int32
#  34  res_day                      33949 non-null  int32
#  35  res_weekday                  33949 non-null  int32
#  36  pricepernight                33949 non-null  float64
# dtypes: datetime64[us](1), float64(2), int32(4), int64(18), str(12)
# memory usage: 9.3 MB

# %% [markdown]
# ## 8. Outlier Removal (IQR Method)

# %%
# Remove negative ADR (invalid)
df_cleanednegative = df[df['adr'] >= 0]

# %%
df_cleanednegative.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 33948 entries, 0 to 40059
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iscanceled                   33948 non-null  int64
#  1   leadtime                     33948 non-null  int64
#  2   arrivaldateyear              33948 non-null  int64
#  3   arrivaldatemonth             33948 non-null  str
#  4   arrivaldateweeknumber        33948 non-null  int64
#  5   arrivaldatedayofmonth        33948 non-null  int64
#  6   staysinweekendnights         33948 non-null  int64
#  7   staysinweeknights            33948 non-null  int64
#  8   adults                       33948 non-null  int64
#  9   children                     33948 non-null  int64
#  10  babies                       33948 non-null  int64
#  11  meal                         33948 non-null  str
#  12  country                      33948 non-null  str
#  13  marketsegment                33948 non-null  str
#  14  distributionchannel          33948 non-null  str
#  15  isrepeatedguest              33948 non-null  int64
#  16  previouscancellations        33948 non-null  int64
#  17  previousbookingsnotcanceled  33948 non-null  int64
#  18  reservedroomtype             33948 non-null  str
#  19  assignedroomtype             33948 non-null  str
#  20  bookingchanges               33948 non-null  int64
#  21  deposittype                  33948 non-null  str
#  22  agent                        33948 non-null  str
#  23  company                      33948 non-null  str
#  24  daysinwaitinglist            33948 non-null  int64
#  25  customertype                 33948 non-null  str
#  26  adr                          33948 non-null  float64
#  27  requiredcarparkingspaces     33948 non-null  int64
#  28  totalofspecialrequests       33948 non-null  int64
#  29  reservationstatus            33948 non-null  str
#  30  reservationstatusdate        33948 non-null  datetime64[us]
#  31  totalstay                    33948 non-null  int64
#  32  res_year                     33948 non-null  int32
#  33  res_month                    33948 non-null  int32
#  34  res_day                      33948 non-null  int32
#  35  res_weekday                  33948 non-null  int32
#  36  pricepernight                33948 non-null  float64
# dtypes: datetime64[us](1), float64(2), int32(4), int64(18), str(12)
# memory usage: 9.3 MB

# %%
df_cleanednegative['adr'].max()
# Out:
# np.float64(508.0)

# %%
Q1 = df_cleanednegative['adr'].quantile(0.25)
Q3 = df_cleanednegative['adr'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower:", lower, "Upper:", upper)
# Out:
# Lower: -72.39999999999999 Upper: 258.0

# %%
upper = df_cleanednegative['adr'].quantile(0.99)
lower = df_cleanednegative['adr'].quantile(0.01)

df_cleanednegative['adr'] = df_cleanednegative['adr'].clip(lower, upper)

# %%
# Optional: normalize
df_cleanednegative['adr_log'] = np.log1p(df_cleanednegative['adr'])

# %%
df_cleanednegative
# Out:
#        iscanceled  leadtime  arrivaldateyear arrivaldatemonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 40055           0       212             2017           August
# 40056           0       169             2017           August
# 40057           0       204             2017           August
# 40058           0       211             2017           August
# 40059           0       161             2017           August
#
#        arrivaldateweeknumber  arrivaldatedayofmonth  staysinweekendnights  \
# 0                         27                      1                     0
# 1                         27                      1                     0
# 2                         27                      1                     0
# 3                         27                      1                     0
# 4                         27                      1                     0
# ...                      ...                    ...                   ...
# 40055                     35                     31                     2
# 40056                     35                     30                     2
# 40057                     35                     29                     4
# 40058                     35                     31                     4
# 40059                     35                     31                     4
#
#        staysinweeknights  adults  children  ...  totalofspecialrequests  \
# 0                      0       2         0  ...                       0
# 1                      0       2         0  ...                       0
# 2                      1       1         0  ...                       0
# 3                      1       1         0  ...                       0
# 4                      2       2         0  ...                       1
# ...                  ...     ...       ...  ...                     ...
# 40055                  8       2         1  ...                       0
# 40056                  9       2         0  ...                       1
# 40057                 10       2         0  ...                       3
# 40058                 10       2         0  ...                       1
# 40059                 10       2         0  ...                       0
#
#       reservationstatus reservationstatusdate totalstay res_year  res_month  \
# 0             Check-Out            2015-07-01         0     2015          7
# 1             Check-Out            2015-07-01         0     2015          7
# 2             Check-Out            2015-07-02         1     2015          7
# 3             Check-Out            2015-07-02         1     2015          7
# 4             Check-Out            2015-07-03         2     2015          7
# ...                 ...                   ...       ...      ...        ...
# 40055         Check-Out            2017-09-10        10     2017          9
# 40056         Check-Out            2017-09-10        11     2017          9
# 40057         Check-Out            2017-09-12        14     2017          9
# 40058         Check-Out            2017-09-14        14     2017          9
# 40059         Check-Out            2017-09-14        14     2017          9
#
#        res_day  res_weekday pricepernight   adr_log
# 0            1            2      0.000000  0.000000
# 1            1            2      0.000000  0.000000
# 2            2            3     75.000000  4.330733
# 3            2            3     75.000000  4.330733
# 4            3            4     98.000000  4.595120
# ...        ...          ...           ...       ...
# 40055       10            6     29.916667  4.508108
# 40056       10            6     67.423333  5.314535
# 40057       12            1     30.714000  5.040647
# 40058       14            3     22.560000  4.734443
# 40059       14            3     19.812000  4.605770
#
# [33948 rows x 38 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.boxplot(x=df['adr'])
plt.title("Before")

plt.subplot(1,2,2)
sns.boxplot(x=df_cleanednegative['adr'])
plt.title("After")

plt.show()

# %% [markdown]
# ## 9. Save Clean Dataset

# %%
df_cleanednegative.to_csv('cleaned_data.csv', index=False)
